# %% [markdown]
# # Comparing CART and MIO methods to create decision trees

# %% [markdown]
# Import packages needed for CART and MIO methods

# %%
import tree as miptree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn import tree
import time
from os import path
import pandas as pd
import dataset as ds
import math

# %%
timelimit = 600
datasets = ['Breast Cancer', 'Car Evaluation', 'Credit Approval', 'Heart Disease', 'Ionosphere', 'Iris', 'Mushroom',
             'Statlog (German Credit Data)', 'Wine', 'Zoo']
alpha = [0, 0.01, 0.1]
depth = [1, 2, 3, 4]
seeds = [1, 2, 3]
train_ratio = 0.5
val_ratio = 0.25
test_ratio = 0.25

# %%
# create or load table
ResCART = pd.DataFrame(columns=['instance', 'depth', 'alpha', 'seed', 'train_acc', 'val_acc', 'test_acc', 'train_time'])
if path.isfile('./res/OCTWS.csv'):
    ResOCTWS = pd.read_csv('./res/OCTWS.csv')
else:
    ResOCTWS = pd.DataFrame(columns=['instance', 'depth', 'alpha', 'seed', 
                                    'train_acc', 'val_acc', 'test_acc', 'train_time', 'gap'])
if path.isfile('./res/OCTNoWS.csv'):
    ResOCTNoWS = pd.read_csv('./res/OCTNoWS.csv')
else:
    ResOCTNoWS = pd.DataFrame(columns=['instance', 'depth', 'alpha', 'seed', 
                                    'train_acc', 'val_acc', 'test_acc', 'train_time', 'gap'])
if path.isfile('./res/OCTWSModified.csv'):
    ResOCTWSModified = pd.read_csv('./res/OCTWSModified.csv')
else:
    ResOCTWSModified = pd.DataFrame(columns=['instance', 'depth', 'alpha', 'seed', 
                                    'train_acc', 'val_acc', 'test_acc', 'train_time', 'gap'])

# %% [markdown]
# # CART

# %%
#CART
for data in datasets:
    # load data
    x, y = ds.loadData(data)
    for s in seeds:
        # split data
        x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=1-train_ratio, random_state=s)
        x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, 
                                                        test_size=test_ratio/(test_ratio+val_ratio), random_state=s)
        # Set min_samples_leaf to 1/25 of the training set size
        min_samples_leaf = math.floor(len(x_train)/25)
        for d in depth:
            for a in alpha:
                clf = tree.DecisionTreeClassifier(max_depth=d, min_samples_leaf=min_samples_leaf, ccp_alpha=a)
                tick = time.time()
                clf.fit(x_train, y_train)
                tock = time.time()
                train_time = tock - tick
                train_acc = accuracy_score(y_train, clf.predict(x_train))
                val_acc = accuracy_score(y_val, clf.predict(x_val))
                test_acc = accuracy_score(y_test, clf.predict(x_test))
                print(data, 'CART-d{}-a{}-s{}'.format(d,a,s), 'train acc:', train_acc, 'val acc:', val_acc)
                row = {'instance':data, 'depth':d, 'alpha':a, 'seed':s, 'train_acc':train_acc, 
                    'val_acc':val_acc, 'test_acc':test_acc, 'train_time':train_time}
                ResCART = ResCART._append(row, ignore_index=True)
                ResCART.to_csv('./res/CART.csv', index=False)
# Out:
# Breast Cancer CART-d1-a0-s1 train acc: 0.7391304347826086 val acc: 0.6376811594202898
# Breast Cancer CART-d1-a0.01-s1 train acc: 0.7391304347826086 val acc: 0.6376811594202898
# Breast Cancer CART-d1-a0.1-s1 train acc: 0.6811594202898551 val acc: 0.6666666666666666
# Breast Cancer CART-d2-a0-s1 train acc: 0.7753623188405797 val acc: 0.6231884057971014
# Breast Cancer CART-d2-a0.01-s1 train acc: 0.7753623188405797 val acc: 0.6231884057971014
# Breast Cancer CART-d2-a0.1-s1 train acc: 0.6811594202898551 val acc: 0.6666666666666
# Zoo CART-d3-a0.1-s1 train acc: 0.8 val acc: 0.96
# Zoo CART-d4-a0-s1 train acc: 0.86 val acc: 1.0
# Zoo CART-d4-a0.01-s1 train acc: 0.86 val acc: 1.0
# Zoo CART-d4-a0.1-s1 train acc: 0.8 val acc: 0.96
# Zoo CART-d1-a0-s2 train acc: 0.56 val acc: 0.68
# Zoo CART-d1-a0.01-s2 train acc: 0.56 val acc: 0.68
# Zoo CART-d1-a0.1-s2 train acc: 0.56 val acc: 0.68
# Zoo CART-d2-a0-s2 train acc: 0.7 val acc: 0.84
# Zoo CART-d2-a0.01-s2 train acc: 0.7 val acc: 0.84
# Zoo CART-d2-a0.1-s2 train acc: 0.7 val acc: 0.84
# Zoo CART-d3-a0-s2 train acc: 0.82 val acc: 0.84
# Zoo CART-d3-a0.01-s2 train acc: 0.82 val acc: 0.84
# Zoo CART-d3-a0.1-s2 train acc: 0.82 val acc: 0.84
# Zoo CART-d4-a0-s2 train acc: 0.92 val acc: 0.84
# Zoo CART-d4-a0.01-s2 train acc: 0.92 val acc: 0.84
# Zoo CART-d4-a0.1-s2 train acc: 0.82 val acc: 0.84
# Zoo CART-d1-a0-s3 train acc: 0.62 val acc: 0.64
# Zoo CART-d1-a0.01-s3 train acc: 0.62 val acc: 0.64
# Zoo CART-d1-a0.1-s3 train acc: 0.62 val acc: 0.64
# Zoo CART-d2-a0-s3 train acc: 0.76 val acc: 0.76
# Zoo CART-d2-a0.01-s3 train acc: 0.76 val acc: 0.76
# Zoo CART-d2-a0.1-s3 train acc: 0.76 val acc: 0.76
# Zoo CART-d3-a0-s3 train acc: 0.84 val acc: 0.8
# Zoo CART-d3-a0.01-s3 train acc: 0.84 val acc: 0.8
# Zoo CART-d3-a0.1-s3 train acc: 0.84 val acc: 0.8
# Zoo CART-d4-a0-s3 train acc: 0.88 val acc: 0.88
# Zoo CART-d4-a0.01-s3 train acc: 0.88 val acc: 0.88
# Zoo CART-d4-a0.1-s3 train acc: 0.84 val acc: 0.8

# %% [markdown]
# # OCT

# %%
for data in datasets:
    # load data
    x, y = ds.loadData(data)
    for s in seeds:
        # data splition
        x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=1-train_ratio, random_state=s)
        x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, 
                                                        test_size=test_ratio/(test_ratio+val_ratio), random_state=s)
        # Set min_samples_leaf to 1/25 of the training set size
        min_samples_leaf = math.floor(len(x_train)/25)
        for d in depth:
            for a in alpha:
                # oct with warm start
                row = ResOCTWS[(ResOCTWS['instance'] == data) & (ResOCTWS['depth'] == d) & 
                              (ResOCTWS['alpha'] == a) & (ResOCTWS['seed'] == s)]
                if len(row):
                    print(data, 'OCTWS-d{}-a{}-s{}'.format(row['depth'].values[0],row['alpha'].values[0], row['seed'].values[0]),
                          'train acc:', row['train_acc'].values[0], 'val acc:', row['val_acc'].values[0],
                          'gap:', row['gap'].values[0])
                else:
                    octree = miptree.optimalDecisionTreeClassifier(max_depth=d, min_samples_leaf=min_samples_leaf, alpha=a, warmstart=True,
                                                                   timelimit=timelimit, output=False)
                    tick = time.time()
                    octree.fit(x_train, y_train)
                    tock = time.time()
                    train_time = tock - tick
                    train_acc = accuracy_score(y_train, octree.predict(x_train))
                    val_acc = accuracy_score(y_val, octree.predict(x_val))
                    test_acc = accuracy_score(y_test, octree.predict(x_test))
                    row = {'instance':data, 'depth':d, 'alpha':a, 'seed':s, 'train_acc':train_acc, 'val_acc':val_acc,
                           'test_acc':test_acc, 'train_time':train_time, 'gap':octree.optgap}
                    ResOCTWS = ResOCTWS._append(row, ignore_index=True)
                    ResOCTWS.to_csv('./res/OCTWS.csv', index=False)
                    print(data, 'OCTWS-d{}-a{}-s{}'.format(d,a,s), 
                          'train acc:', train_acc, 'val acc:', val_acc, 'train_time:', train_time, 'gap:', octree.optgap)
                    #print(row)
                    
                # oct without warm start
                row = ResOCTNoWS[(ResOCTNoWS['instance'] == data) & (ResOCTNoWS['depth'] == d) & 
                              (ResOCTNoWS['alpha'] == a) & (ResOCTNoWS['seed'] == s)]
                if len(row):
                    print(data, 'OctNoWS-d{}-a{}-s{}'.format(row['depth'].values[0],row['alpha'].values[0], row['seed'].values[0]),
                          'train acc:', row['train_acc'].values[0], 'val acc:', row['val_acc'].values[0],
                          'gap:', row['gap'].values[0])
                else:
                    octree = miptree.optimalDecisionTreeClassifier(max_depth=d, min_samples_leaf=min_samples_leaf, alpha=a, warmstart=False,
                                                                   timelimit=timelimit, output=False)
                    tick = time.time()
                    octree.fit(x_train, y_train)
                    tock = time.time()
                    train_time = tock - tick
                    train_acc = accuracy_score(y_train, octree.predict(x_train))
                    val_acc = accuracy_score(y_val, octree.predict(x_val))
                    test_acc = accuracy_score(y_test, octree.predict(x_test))
                    row = {'instance':data, 'depth':d, 'alpha':a, 'seed':s, 'train_acc':train_acc, 'val_acc':val_acc,
                           'test_acc':test_acc, 'train_time':train_time, 'gap':octree.optgap}
                    ResOCTNoWS = ResOCTNoWS._append(row, ignore_index=True)
                    ResOCTNoWS.to_csv('./res/OCTNoWS.csv', index=False)
                    print(data, 'OCTNoWS-d{}-a{}-s{}'.format(d,a,s), 
                          'train acc:', train_acc, 'val acc:', val_acc, 'train_time:', train_time, 'gap:', octree.optgap)
                    #print(row)

# %% [markdown]
# # OCT modifed version

# %%
for data in datasets:
    # load data
    x, y = ds.loadData(data)
    for s in seeds:
        # data splition
        x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=1-train_ratio, random_state=s)
        x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, 
                                                        test_size=test_ratio/(test_ratio+val_ratio), random_state=s)
        # Set min_samples_leaf to 1/25 of the training set size
        min_samples_leaf = math.floor(len(x_train)/25)
        for d in depth:
            for a in alpha:
                # oct with warm start
                row = ResOCTWSModified[(ResOCTWSModified['instance'] == data) & (ResOCTWSModified['depth'] == d) & 
                              (ResOCTWSModified['alpha'] == a) & (ResOCTWSModified['seed'] == s)]
                if len(row):
                    print(data, 'OCTWSModified-d{}-a{}-s{}'.format(row['depth'].values[0],row['alpha'].values[0], row['seed'].values[0]),
                          'train acc:', row['train_acc'].values[0], 'val acc:', row['val_acc'].values[0],
                          'gap:', row['gap'].values[0])
                else:
                    octree = tree.optimalDecisionTreeClassifierModified(max_depth=d, min_samples_leaf=min_samples_leaf, alpha=a, warmstart=True,
                                                                    timelimit=timelimit, output=False)
                    tick = time.time()
                    octree.fit(x_train, y_train)
                    tock = time.time()
                    train_time = tock - tick
                    train_acc = accuracy_score(y_train, octree.predict(x_train))
                    val_acc = accuracy_score(y_val, octree.predict(x_val))
                    test_acc = accuracy_score(y_test, octree.predict(x_test))
                    row = {'instance':data, 'depth':d, 'alpha':a, 'seed':s, 'train_acc':train_acc, 'val_acc':val_acc,
                           'test_acc':test_acc, 'train_time':train_time, 'gap':octree.optgap}
                    ResOCTWSModified = ResOCTWSModified._append(row, ignore_index=True)
                    ResOCTWSModified.to_csv('./res/OCTWSModified.csv', index=False)
                    print(data, 'OCTWSModified-d{}-a{}-s{}'.format(d,a,s), 
                            'train acc:', train_acc, 'val acc:', val_acc, 'train_time:', train_time, 'gap:', octree.optgap)
                    #print(row)
# Out:
# Breast Cancer OCTWSModified-d1-a0.0-s1 train acc: 0.7391304347826086 val acc: 0.6376811594202898 gap: 0.0
# Breast Cancer OCTWSModified-d1-a0.01-s1 train acc: 0.7391304347826086 val acc: 0.6376811594202898 gap: 0.0
# Breast Cancer OCTWSModified-d1-a0.1-s1 train acc: 0.6811594202898551 val acc: 0.6666666666666666 gap: 0.0
# Breast Cancer OCTWSModified-d2-a0.0-s1 train acc: 0.782608695652174 val acc: 0.6231884057971014 gap: 0.0
# Breast Cancer OCTWSModified-d2-a0.01-s1 train acc: 0.782608695652174 val acc: 0.6231884057971014 gap: 0.0
# Breast Cancer OCTWSModified-d2-a0.1-s1 train acc: 0.6811594202898551 val acc: 0.6666666666666666 gap: 0.0
# Breast Cancer OCTWSModified-d3-a0.0-s1 train acc: 0.8260869565217391 val acc: 0.6956521739130435 gap: 1.0
# Breast Cancer OCTWSModified-d3-a0.01-s1 train acc: 0.8260869565217391 val acc: 0.6956521739130435 gap: 0.8689895470383275
# Breast Cancer OCTWSModified-d3-a0.1-s1 train acc: 0.6811594202898551 val acc: 0.6666666666666666 gap: 0.1227272727272725
# Breast Cancer OCTWSModified-d4-a0.0-s1 train acc: 0.8115942028985508 val acc: 0.6666666666666666 gap: 1.0
# Breast Cancer OCTWSModified-d4-a0.01-s1 train acc: 0.8405797101449275 val acc: 0.7101449275362319 gap: 0.9145527042031776
# Breast Cancer OCTWSModified-d4-a0.1-s1 train acc: 0.6811594202898551 val acc: 0.6666666666666666 gap: 0.336363636363639
# Breast Cancer OCTWSModified-d1-a0.0-s2 train acc: 0.7536231884057971 val acc: 0.7246376811594203 gap: 0.0
# Breast Cancer OCTWSModified-d1-a0.01-s2 train acc: 0.7536231884057971 val acc: 0.7246376811594203 gap: 0.0
# Breast Cancer OCTWSModified-d1-a0.1-s2 train acc: 0.6884057971014492 val acc: 0.7101449275362319 gap: 0.0
# Breast Cancer OCTWSModified-d2-a0.0-s2 train acc: 0.8043478260869565 val acc: 0.6956521739130435 gap: 0.0
# Breast Cancer OCTWSModified-d2-a0.01-s2 train acc: 0.8043478260869565 val acc: 0.6956521739130435 gap: 0.0
# Breast Cancer OCTWSModified-d2-a0.1-s2 train acc: 0.6884057971014492 val acc: 0.7101449275362319 gap: 0.0
# Breast Cancer OCTWSModified-d3-a0.0-s2 train acc: 0.8333333333333334 val acc: 0.6521739130434783 gap: 1.0
# Breast Cancer OCTWSModified-d3-a0.01-s2 train acc: 0.8043478260869565 val acc: 0.7391304347826086 gap: 0.8740157480314962
# Breast Cancer OCTWSModified-d3-a0.1-s2 train acc: 0.6884057971014492 val acc: 0.7101449275362319 gap: 0.0
# Breast Cancer OCTWSModified-d4-a0.0-s2 train acc: 0.8333333333333334 val acc: 0.6666666666666666 gap: 1.0
# Breast Cancer OCTWSModified-d4-a0.01-s2 train acc: 0.8260869565217391 val acc: 0.6521739130434783 gap: 0.9070146818923328
# Breast Cancer OCTWSModified-d4-a0.1-s2 train acc: 0.6884057971014492 val acc: 0.7101449275362319 gap: 0.3023255813953484
# Breast Cancer OCTWSModified-d1-a0.0-s3 train acc: 0.7608695652173914 val acc: 0.7536231884057971 gap: 0.0
# Breast Cancer OCTWSModified-d1-a0.01-s3 train acc: 0.7608695652173914 val acc: 0.7536231884057971 gap: 0.0
# Breast Cancer OCTWSModified-d1-a0.1-s3 train acc: 0.7391304347826086 val acc: 0.7101449275362319 gap: 0.0
# Breast Cancer OCTWSModified-d2-a0.0-s3 train acc: 0.8043478260869565 val acc: 0.7971014492753623 gap: 0.0
# Breast Cancer OCTWSModified-d2-a0.01-s3 train acc: 0.8043478260869565 val acc: 0.7971014492753623 gap: 0.0
# Breast Cancer OCTWSModified-d2-a0.1-s3 train acc: 0.7391304347826086 val acc: 0.7101449275362319 gap: 0.0
# Breast Cancer OCTWSModified-d3-a0.0-s3 train acc: 0.8405797101449275 val acc: 0.7971014492753623 gap: 1.0
# Breast Cancer OCTWSModified-d3-a0.01-s3 train acc: 0.8260869565217391 val acc: 0.782608695652174 gap: 0.8668091168091165
# Breast Cancer OCTWSModified-d3-a0.1-s3 train acc: 0.7391304347826086 val acc: 0.7101449275362319 gap: 0.0
# Breast Cancer OCTWSModified-d4-a0.0-s3 train acc: 0.8478260869565217 val acc: 0.7971014492753623 gap: 1.0
# Breast Cancer OCTWSModified-d4-a0.01-s3 train acc: 0.8043478260869565 val acc: 0.7971014492753623 gap: 0.8925619834710742
# Breast Cancer OCTWSModified-d4-a0.1-s3 train acc: 0.7391304347826086 val acc: 0.7101449275362319 gap: 0.0
# Car Evaluation OCTWSModified-d1-a0.0-s1 train acc: 0.7013888888888888 val acc: 0.6759259259259259 gap: 0.0
# Car Evaluation OCTWSModified-d1-a0.01-s1 train acc: 0.7013888888888888 val acc: 0.6759259259259259 gap: 0.0
# Car Evaluation OCTWSModified-d1-a0.1-s1 train acc: 0.7013888888888888 val acc: 0.6759259259259259 gap: 0.0
# Car Evaluation OCTWSModified-d2-a0.0-s1 train acc: 0.7638888888888888 val acc: 0.7476851851851852 gap: 0.9705882352941176
# Car Evaluation OCTWSModified-d2-a0.01-s1 train acc: 0.7638888888888888 val acc: 0.7476851851851852 gap: 0.0
# Car Evaluation OCTWSModified-d2-a0.1-s1 train acc: 0.7013888888888888 val acc: 0.6759259259259259 gap: 0.0
# Car Evaluation OCTWSModified-d3-a0.0-s1 train acc: 0.7696759259259259 val acc: 0.7407407407407407 gap: 0.9899497487437188
# Car Evaluation OCTWSModified-d3-a0.01-s1 train acc: 0.8009259259259259 val acc: 0.8009259259259259 gap: 0.9008980946664796
# Car Evaluation OCTWSModified-d3-a0.1-s1 train acc: 0.7013888888888888 val acc: 0.6759259259259259 gap: 0.5238889050168135
# Car Evaluation OCTWSModified-d4-a0.0-s1 train acc: 0.7800925925925926 val acc: 0.7337962962962963 gap: 0.9947368421052633
# Car Evaluation OCTWSModified-d4-a0.01-s1 train acc: 0.7013888888888888 val acc: 0.6759259259259259 gap: 0.972638007751938
# Car Evaluation OCTWSModified-d4-a0.1-s1 train acc: 0.7013888888888888 val acc: 0.6759259259259259 gap: 0.7042951614497528
# Car Evaluation OCTWSModified-d1-a0.0-s2 train acc: 0.6967592592592593 val acc: 0.7268518518518519 gap: 0.0
# Car Evaluation OCTWSModified-d1-a0.01-s2 train acc: 0.6967592592592593 val acc: 0.7268518518518519 gap: 0.0
# Car Evaluation OCTWSModified-d1-a0.1-s2 train acc: 0.6967592592592593 val acc: 0.7268518518518
gap: 1.0
# Statlog (German Credit Data) OCTWSModified-d2-a0.01-s1 train acc: 0.728 val acc: 0.688 gap: 0.949758661943611
# Statlog (German Credit Data) OCTWSModified-d2-a0.1-s1 train acc: 0.688 val acc: 0.684 gap: 0.5589743589743589
# Statlog (German Credit Data) OCTWSModified-d3-a0.0-s1 train acc: 0.724 val acc: 0.716 gap: 1.0
# Statlog (German Credit Data) OCTWSModified-d3-a0.01-s1 train acc: 0.722 val acc: 0.712 gap: 0.9528379489991774
# Statlog (German Credit Data) OCTWSModified-d3-a0.1-s1 train acc: 0.688 val acc: 0.684 gap: 0.5589743589743589
# Statlog (German Credit Data) OCTWSModified-d4-a0.0-s1 train acc: 0.736 val acc: 0.736 gap: 1.0
# Statlog (German Credit Data) OCTWSModified-d4-a0.01-s1 train acc: 0.722 val acc: 0.7 gap: 0.9528379489991774
# Statlog (German Credit Data) OCTWSModified-d4-a0.1-s1 train acc: 0.688 val acc: 0.684 gap: 0.5589743589743589
# Statlog (German Credit Data) OCTWSModified-d1-a0.0-s2 train acc: 0.716 val acc: 0.676 gap: 0.0
# Statlog (German Credit Data) OCTWSModified-d1-a0.01-s2 train acc: 0.716 val acc: 0.676 gap: 0.0
# Statlog (German Credit Data) OCTWSModified-d1-a0.1-s2 train acc: 0.716 val acc: 0.676 gap: 0.0
# Statlog (German Credit Data) OCTWSModified-d2-a0.0-s2 train acc: 0.738 val acc: 0.696 gap: 1.0
# Statlog (German Credit Data) OCTWSModified-d2-a0.01-s2 train acc: 0.716 val acc: 0.676 gap: 0.9495774647887324
# Statlog (German Credit Data) OCTWSModified-d2-a0.1-s2 train acc: 0.716 val acc: 0.676 gap: 0.4957746478873218
# Statlog (German Credit Data) OCTWSModified-d3-a0.0-s2 train acc: 0.746 val acc: 0.704 gap: 1.0
# Statlog (German Credit Data) OCTWSModified-d3-a0.01-s2 train acc: 0.716 val acc: 0.676 gap: 0.9495774647887324
# Statlog (German Credit Data) OCTWSModified-d3-a0.1-s2 train acc: 0.716 val acc: 0.676 gap: 0.4957746478873218
# Statlog (German Credit Data) OCTWSModified-d4-a0.0-s2 train acc: 0.764 val acc: 0.656 gap: 1.0
# Statlog (German Credit Data) OCTWSModified-d4-a0.01-s2 train acc: 0.762 val acc: 0.672 gap: 0.9477016654492332
# Statlog (German Credit Data) OCTWSModified-d4-a0.1-s2 train acc: 0.716 val acc: 0.676 gap: 0.4957746478873218
# Statlog (German Credit Data) OCTWSModified-d1-a0.0-s3 train acc: 0.71 val acc: 0.704 gap: 0.0
# Statlog (German Credit Data) OCTWSModified-d1-a0.01-s3 train acc: 0.71 val acc: 0.704 gap: 0.0
# Statlog (German Credit Data) OCTWSModified-d1-a0.1-s3 train acc: 0.682 val acc: 0.712 gap: 0.0
# Statlog (German Credit Data) OCTWSModified-d2-a0.0-s3 train acc: 0.73 val acc: 0.712 gap: 1.0
# Statlog (German Credit Data) OCTWSModified-d2-a0.01-s3 train acc: 0.722 val acc: 0.732 gap: 0.9532300096008778
# Statlog (German Credit Data) OCTWSModified-d2-a0.1-s3 train acc: 0.682 val acc: 0.712 gap: 0.5710691823899371
# Statlog (German Credit Data) OCTWSModified-d3-a0.0-s3 train acc: 0.746 val acc: 0.7 gap: 1.0
# Statlog (German Credit Data) OCTWSModified-d3-a0.01-s3 train acc: 0.71 val acc: 0.704 gap: 0.9540462233003166
# Statlog (German Credit Data) OCTWSModified-d3-a0.1-s3 train acc: 0.682 val acc: 0.712 gap: 0.5710691823899371
# Statlog (German Credit Data) OCTWSModified-d4-a0.0-s3 train acc: 0.752 val acc: 0.648 gap: 1.0
# Statlog (German Credit Data) OCTWSModified-d4-a0.01-s3 train acc: 0.744 val acc: 0.676 gap: 0.951849759954815
# Statlog (German Credit Data) OCTWSModified-d4-a0.1-s3 train acc: 0.682 val acc: 0.712 gap: 0.5710691823899371
# Wine OCTWSModified-d3-a0.0-s3 train acc: 1.0 val acc: 0.8863636363636364 gap: 0.0
# Wine OCTWSModified-d3-a0.01-s3 train acc: 1.0 val acc: 0.9545454545454546 gap: 0.0
# Wine OCTWSModified-d3-a0.1-s3 train acc: 0.9662921348314608 val acc: 0.9090909090909092 gap: 0.0
# Wine OCTWSModified-d4-a0.0-s3 train acc: 1.0 val acc: 0.9772727272727272 gap: 0.0
# Wine OCTWSModified-d4-a0.01-s3 train acc: 1.0 val acc: 0.8863636363636364 gap: 0.0
# Wine OCTWSModified-d4-a0.1-s3 train acc: 0.9662921348314608 val acc: 0.8409090909090909 gap: 0.0
# Zoo OCTWSModified-d1-a0.0-s1 train acc: 0.56 val acc: 0.72 gap: 0.0
# Zoo OCTWSModified-d1-a0.01-s1 train acc: 0.56 val acc: 0.72 gap: 0.0
# Zoo OCTWSModified-d1-a0.1-s1 train acc: 0.56 val acc: 0.72 gap: 0.0
# Zoo OCTWSModified-d2-a0.0-s1 train acc: 0.78 val acc: 0.92 gap: 0.0
# Zoo OCTWSModified-d2-a0.01-s1 train acc: 0.78 val acc: 0.92 gap: 0.0
# Zoo OCTWSModified-d2-a0.1-s1 train acc: 0.78 val acc: 0.96 gap: 0.0
# Zoo OCTWSModified-d3-a0.0-s1 train acc: 0.94 val acc: 0.84 gap: 0.0
# Zoo OCTWSModified-d3-a0.01-s1 train acc: 0.94 val acc: 0.84 gap: 0.0
# Zoo OCTWSModified-d3-a0.1-s1 train acc: 0.9 val acc: 0.92 gap: 0.0
# Zoo OCTWSModified-d4-a0.0-s1 train acc: 0.98 val acc: 0.84 gap: 1.0
# Zoo OCTWSModified-d4-a0.01-s1 train acc: 0.98 val acc: 0.88 gap: 0.4711538461538508
# Zoo OCTWSModified-d4-a0.1-s1 train acc: 0.98 val acc: 0.88 gap: 0.1525423728813567
# Zoo OCTWSModified-d1-a0.0-s2 train acc: 0.56 val acc: 0.68 gap: 0.0
# Zoo OCTWSModified-d1-a0.01-s2 train acc: 0.56 val acc: 0.68 gap: 0.0
# Zoo OCTWSModified-d1-a0.1-s2 train acc: 0.56 val acc: 0.68 gap: 0.0
# Zoo OCTWSModified-d2-a0.0-s2 train acc: 0.8 val acc: 0.84 gap: 0.0
# Zoo OCTWSModified-d2-a0.01-s2 train acc: 0.8 val acc: 0.84 gap: 0.0
# Zoo OCTWSModified-d2-a0.1-s2 train acc: 0.8 val acc: 0.84 gap: 0.0
# Zoo OCTWSModified-d3-a0.0-s2 train acc: 0.96 val acc: 0.84 gap: 0.0
# Zoo OCTWSModified-d3-a0.01-s2 train acc: 0.96 val acc: 0.84 gap: 0.0
# Zoo OCTWSModified-d3-a0.1-s2 train acc: 0.92 val acc: 0.84 gap: 0.0
# Zoo OCTWSModified-d4-a0.0-s2 train acc: 0.98 val acc: 0.72 gap: 0.0
# Zoo OCTWSModified-d4-a0.01-s2 train acc: 0.98 val acc: 0.84 gap: 0.0
# Zoo OCTWSModified-d4-a0.1-s2 train acc: 0.98 val acc: 0.84 gap: 0.0600000000000007
# Zoo OCTWSModified-d1-a0.0-s3 train acc: 0.62 val acc: 0.64 gap: 0.0
# Zoo OCTWSModified-d1-a0.01-s3 train acc: 0.62 val acc: 0.64 gap: 0.0
# Zoo OCTWSModified-d1-a0.1-s3 train acc: 0.62 val acc: 0.64 gap: 0.0
# Zoo OCTWSModified-d2-a0.0-s3 train acc: 0.82 val acc: 0.8 gap: 0.0
# Zoo OCTWSModified-d2-a0.01-s3 train acc: 0.82 val acc: 0.8 gap: 0.0
# Zoo OCTWSModified-d2-a0.1-s3 train acc: 0.82 val acc: 0.8 gap: 0.0
# Zoo OCTWSModified-d3-a0.0-s3 train acc: 0.94 val acc: 0.92 gap: 0.0
# Zoo OCTWSModified-d3-a0.01-s3 train acc: 0.94 val acc: 0.92 gap: 2.275469695450595e-07
# Zoo OCTWSModified-d3-a0.1-s3 train acc: 0.9 val acc: 0.84 gap: 0.0
# Zoo OCTWSModified-d4-a0.0-s3 train acc: 0.96 val acc: 0.92 gap: 1.0
# Zoo OCTWSModified-d4-a0.01-s3 train acc: 0.96 val acc: 0.92 gap: 0.6369426751592349
# Zoo OCTWSModified-d4-a0.1-s3 train acc: 0.94 val acc: 0.92 gap: 0.2000000000000014

# %% [markdown]
# # Intances where OCT failed to predict out of sample observation points

# %%
datasets = ["Ionosphere", "Iris", "Statlog (German Credit Data)","Wine"]
alpha = [0]
depth = [4]
seeds = [1, 2, 3]
for data in datasets:
    # load data
    x, y = ds.loadData(data)
    for s in seeds:
        # data splition
        x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=1-train_ratio, random_state=s)
        x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, 
                                                        test_size=test_ratio/(test_ratio+val_ratio), random_state=s)
        # Set min_samples_leaf to 1/25 of the training set size
        min_samples_leaf = math.floor(len(x_train)/25)
        for d in depth:
            for a in alpha:
                octree = miptree.optimalDecisionTreeClassifier(max_depth=d, min_samples_leaf=min_samples_leaf, alpha=a, warmstart=True,
                                                                timelimit=timelimit, output=False)
                tick = time.time()
                octree.fit(x_train, y_train)
                tock = time.time()
                train_time = tock - tick
                train_acc = accuracy_score(y_train, octree.predict(x_train))
                print(data, 'OCTWS-d{}-a{}-s{}'.format(d,a,s), 
                        'train acc:', train_acc, 'train_time:', train_time, 'gap:', octree.optgap)
                #print(row)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-10-02
# Ionosphere OCTWS-d4-a0-s1 train acc: 0.9257142857142857 train_time: 601.3799159526825 gap: 1.0
# Ionosphere OCTWS-d4-a0-s2 train acc: 0.9542857142857143 train_time: 601.3272738456726 gap: 1.0
# Ionosphere OCTWS-d4-a0-s3 train acc: 0.88 train_time: 601.0696859359741 gap: 1.0
# Iris OCTWS-d4-a0-s1 train acc: 1.0 train_time: 424.57993483543396 gap: 0.0
# Iris OCTWS-d4-a0-s2 train acc: 1.0 train_time: 26.140833139419556 gap: 0.0
# Iris OCTWS-d4-a0-s3 train acc: 1.0 train_time: 10.247819900512695 gap: 0.0
# Statlog (German Credit Data) OCTWS-d4-a0-s1 train acc: 0.722 train_time: 602.2233679294586 gap: 1.0
# Statlog (German Credit Data) OCTWS-d4-a0-s2 train acc: 0.764 train_time: 602.7167911529541 gap: 1.0
# Statlog (German Credit Data) OCTWS-d4-a0-s3 train acc: 0.744 train_time: 602.5008709430695 gap: 1.0
# Wine OCTWS-d4-a0-s1 train acc: 1.0 train_time: 15.263780117034912 gap: 0.0
# Wine OCTWS-d4-a0-s2 train acc: 1.0 train_time: 9.770865201950073 gap: 0.0
# Wine OCTWS-d4-a0-s3 train acc: 1.0 train_time: 11.898742914199829 gap: 0.0
